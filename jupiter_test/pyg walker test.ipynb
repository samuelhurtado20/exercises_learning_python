# %%
import pygwalker as pyg
import pandas as pd

# %%
df = pd.read_csv('https://qasynergystorage.blob.core.windows.net/qasynergycontainer/uploads/RRHH%202.csv', encoding='utf-8')
df
# Out:
#                           Title                             Recruiter  \
# 0              Jose Luis Garcia  Maria de los Angeles Oliveros Molano
# 1            ANTHONY HERRA LARA  Maria de los Angeles Oliveros Molano
# 2             Eduardo Caballero  Maria de los Angeles Oliveros Molano
# 3                Anahí Quiñones  Maria de los Angeles Oliveros Molano
# 4            William Ortiz Romo  Maria de los Angeles Oliveros Molano
# ...                         ...                                   ...
# 1688              Randy Rosario          Baldomero Rivadeneira Romero
# 1689          Richard Hernandez  Maria de los Angeles Oliveros Molano
# 1690             Pablo Villalba                      Clara Avellaneda
# 1691  Giancarlo David Hernandez                 Aime Velasco Arellano
# 1692             Santiago Rojas         Angela Patricia Camargo Ramos
#
#             Category                  Role          Skill Seniority  \
# ...

# %%
pyg.walk(df, dark="light" )
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-000623087e5e597ewxOHT0BX5h8QafRz" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "000623087e5e597ewxOHT0BX5h8QafRz") {
#             var iframe = document.getElementById("gwalker-000623087e5e597ewxOHT0BX5h8QafRz");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>
