# %% [markdown]
# # Intro python data science
# ## Práctica 06: gráficas con matplotlib
#
# Vamos a ver cómo hacer:
# * Punto 1: gráficas de 📈
# * Punto 2: gráficas de 📊
# * Punto 3: gráficas de 🥧🎂

# %% [markdown]
# # Punto 0:

# %%
# importar pandas
import pandas as pd

# %%
# datos de RRSS 2020
fbk = ['Facebook', 2449, True, 2006]
twt = ['Twitter', 339, False, 2006]
ig = ['Instagram', 1000, True, 2010]
yt = ['YouTube', 2000, False, 2005]
lkn = ['LinkedIn', 663, False, 2003]
wsp = ['WhatsApp', 1600, True, 2009]

# lista con datos
lista_rrss = [fbk, twt, ig, yt, lkn, wsp]

# crear dataframe a partir de listas
df =pd.DataFrame(lista_rrss,
            columns = ['Nombre', 'Cantidad', 'ES_FBK', 'Año'])
df
# Out:
#       Nombre  Cantidad  ES_FBK   Año
# 0   Facebook      2449    True  2006
# 1    Twitter       339   False  2006
# 2  Instagram      1000    True  2010
# 3    YouTube      2000   False  2005
# 4   LinkedIn       663   False  2003
# 5   WhatsApp      1600    True  2009

# %%
# matplotlib basics 101

# %%
# importar matplotlib
import matplotlib.pyplot as plt

# %%
# ejemplo super mega básico
x=[1,2,3,4,5]
y=[x ** 3 for x in x]
print(y)
plt.plot(x,y)
plt.show()
# Out:
# [1, 8, 27, 64, 125]

# %% [markdown]
# # Punto 1:

# %%
# gráfico de líneas utilizando matplotlib
plt.plot(df['Nombre'], df['Cantidad'])
plt.show()

# %%
# gráfico de puntos utilizando matplotlib
plt.scatter(df['Nombre'], df['Cantidad'])
plt.show()

# %%
# EXTRA: cómo hacer lo mismo con métodos de un dataframe de pandas
df.plot(kind='scatter', x='Nombre', y='Cantidad')
# Out:
# <Axes: xlabel='Nombre', ylabel='Cantidad'>

# %% [markdown]
# # Punto 2:

# %%
# hacer gráficos de barras

# %%
# gráfico de puntos utilizando matplotlib
plt.bar(df['Nombre'], df['Cantidad'])
plt.show()

# %%
# gráfico de barras ordenado
df_sorted = df.sort_values('Cantidad', ascending=True)
plt.bar(df_sorted['Nombre'], df_sorted['Cantidad'])
plt.show()

# %%
# gráfico de barras ordenado
df_sorted = df.sort_values('Cantidad', ascending=False)
plt.bar(df_sorted['Nombre'], df_sorted['Cantidad'])
plt.show()

# %%
# gráfico de barras ordenado y con color


# b: blue.
# g: green.
# r: red.
# c: cyan.
# m: magenta.
# y: yellow.
# k: black.
# w: white.
df_sorted = df.sort_values('Cantidad', ascending=False)
plt.bar(df_sorted['Nombre'], df_sorted['Cantidad'], color=['#3b5998', '#FF0000', '#25d366', '#8a3ab9', '#0e76a8', '#00acee'])
plt.show()

# %% [markdown]
# # Punto 3:

# %%
# Hacer gráficas de pastel/tarta/torta/pie

# %%
# gráfico de puntos utilizando matplotlib
plt.pie(df['Cantidad'], labels=df['Nombre'])
plt.show()

# %%
lista_col_rrss=['#3b5998', '#FF0000', '#25d366', '#8a3ab9', '#0e76a8', '#00acee']

# %%
# grafico de puntos utilizando matplotlib
plt.pie(df_sorted['Cantidad'], labels=df_sorted['Nombre'], colors=['#3b5998', '#FF0000', '#25d366', '#8a3ab9', '#0e76a8', '#00acee'])
plt.show()
